# %% [markdown]
# # Project Wrangle and Analyze Data - Angelos Gkouveris

# %% [markdown]
# ## Table of Contents
# <ul>
# <li><a href="#gathering">Gathering Data</a></li>
# <li><a href="#Assessing">Assessing Data</a></li>
# <li><a href="#Cleaning">Cleaning Data</a></li>
# <li><a href="#Storing ">Storing and Acting on Wrangled Data</a></li>
# </ul>

# %% [markdown]
# <a id='gathering'></a>
# # Gathering Data

# %%
#Import Libraries
import requests 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read tsv file
import requests
import pandas as pd
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)
with open('image_predictions.tsv', 'wb') as file:
    file.write(response.content)
    
image_predictions  = pd.read_csv('image_predictions.tsv', sep='\t')
image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
# Read csv file
twitter = pd.read_csv('twitter-archive-enhanced.csv')
twitter.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
# Read txt file
tweet = pd.read_csv('tweet_json.txt', encoding = 'utf-8')
tweet.set_index('tweet_id', inplace = True)
tweet.head()
# Out:
#                     favorites  retweets  user_followers  user_favourites  \
# tweet_id
# 892420643555336193      38664      8550         7060871           135116
# 892177421306343426      33127      6287         7060871           135116
# 891815181378084864      24939      4166         7060871           135116
# 891689557279858688      42044      8673         7060871           135116
# 891327558926688256      40194      9439         7060871           135116
#
#                               date_time
# tweet_id
# 892420643555336193  2017-08-01 16:23:56
# 892177421306343426  2017-08-01 00:17:27
# 891815181378084864  2017-07-31 00:18:03
# 891689557279858688  2017-07-30 15:58:51
# 891327558926688256  2017-07-29 16:00:24

# %% [markdown]
# <a id='Assessing'></a>
# # Assessing Data
# In the cells below, each column of each table in this project dataset is described.This task is part of visual assessment in pandas.

# %%
# Display the image_predictions table
image_predictions
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
image_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_predictions.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
#Display "WeRateDogs Twitter archive" table
twitter
twitter.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
#Display twitter table
twitter.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
# Find descriptive statistics of twitter table
twitter.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
#Display " tweet's retweet count" table
tweet
tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2344 entries, 892420643555336193 to 666020888022790149
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   favorites        2344 non-null   int64
#  1   retweets         2344 non-null   int64
#  2   user_followers   2344 non-null   int64
#  3   user_favourites  2344 non-null   int64
#  4   date_time        2344 non-null   object
# dtypes: int64(4), object(1)
# memory usage: 109.9+ KB

# %%
tweet.head()
# Out:
#                     favorites  retweets  user_followers  user_favourites  \
# tweet_id
# 892420643555336193      38664      8550         7060871           135116
# 892177421306343426      33127      6287         7060871           135116
# 891815181378084864      24939      4166         7060871           135116
# 891689557279858688      42044      8673         7060871           135116
# 891327558926688256      40194      9439         7060871           135116
#
#                               date_time
# tweet_id
# 892420643555336193  2017-08-01 16:23:56
# 892177421306343426  2017-08-01 00:17:27
# 891815181378084864  2017-07-31 00:18:03
# 891689557279858688  2017-07-30 15:58:51
# 891327558926688256  2017-07-29 16:00:24

# %%
tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2344 entries, 892420643555336193 to 666020888022790149
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   favorites        2344 non-null   int64
#  1   retweets         2344 non-null   int64
#  2   user_followers   2344 non-null   int64
#  3   user_favourites  2344 non-null   int64
#  4   date_time        2344 non-null   object
# dtypes: int64(4), object(1)
# memory usage: 109.9+ KB

# %% [markdown]
# ## Quality
# ##### `image_predictions` table
# - Rename columns (p1,p2,p2) to (prediction1,prediction2,prediction3).
# - Rename columns (p1_conf,p2_conf,p3_conf) to (prediction1_conf,prediction2_conf,prediction3_conf).
# - Rename columns (p1_dog,p2_dog,p3_dog) to (prediction1_dog,prediction2_dog,prediction3_dog).
# - Change tweet_id to object instead of int.
#
# ##### `twitter` table
# - Drop the unnecessary collumns with most nulls.
# - Change timestamp to datetime instead of object.
# - Change tweet_id to object instead of int.
# - Drop Max rating numerator 1776	which should be wrong.
# - Drop row with rating denominator not equal to 10.(always the denominator must be 10)
#
# ##### `tweet` table
# - Drop unnecessary collumns like (retweets, user_followers).
#
# ## Tideness
# - Create a column Total Rating which includes (rating_numerator/rating_denominator) in twitter table.
# - Combine two dataframes.

# %% [markdown]
# <a id='Cleaning'></a>
# # Cleaning Data

# %%
#Create a copy for each table
image_predictions_clean = image_predictions.copy()
twitter_clean = twitter.copy()
tweet_clean = tweet.copy()

# %% [markdown]
# ## image_predictions table

# %% [markdown]
# ##### Define
# Rename columns (p1,p2,p2) to (prediction1,prediction2,prediction3).

# %% [markdown]
# ##### Code

# %%
#Rename columns
image_predictions_clean = image_predictions_clean.rename(columns={"p1": "Prediction1", "p2": "Prediction2","p3": "Prediction3"})

# %% [markdown]
# ##### Test

# %%
image_predictions_clean.head(0)
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, Prediction1, p1_conf, p1_dog, Prediction2, p2_conf, p2_dog, Prediction3, p3_conf, p3_dog]
# Index: []

# %% [markdown]
# ##### Define
#  Rename columns (p1_conf,p2_conf,p3_conf) to (prediction1_conf,prediction2_conf,prediction3_conf).

# %% [markdown]
# ##### Code

# %%
#Rename columns
image_predictions_clean = image_predictions_clean.rename(columns={"p1_conf": "prediction1_conf", "p2_conf": "prediction2_conf","p3_conf": "prediction3_conf"})

# %% [markdown]
# ##### Test

# %%
image_predictions_clean.head(0)
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, Prediction1, prediction1_conf, p1_dog, Prediction2, prediction2_conf, p2_dog, Prediction3, prediction3_conf, p3_dog]
# Index: []

# %% [markdown]
# ##### Define
# Rename columns (p1_dog,p2_dog,p3_dog) to (prediction1_dog,prediction2_dog,prediction3_dog).

# %% [markdown]
# ##### Code

# %%
image_predictions_clean = image_predictions_clean.rename(columns={"p1_dog": "prediction1_dog", "p2_dog": "prediction2_dog","p3_dog": "prediction3_dog"})

# %% [markdown]
# ##### Test

# %%
image_predictions_clean.head(0)
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, Prediction1, prediction1_conf, prediction1_dog, Prediction2, prediction2_conf, prediction2_dog, Prediction3, prediction3_conf, prediction3_dog]
# Index: []

# %% [markdown]
# ##### Define
# Change tweet_id to object instead of int.

# %% [markdown]
# ##### Code

# %%
image_predictions_clean['tweet_id'] = image_predictions_clean['tweet_id'].astype('str')

# %% [markdown]
# ##### Test

# %%
image_predictions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tweet_id          2075 non-null   object
#  1   jpg_url           2075 non-null   object
#  2   img_num           2075 non-null   int64
#  3   Prediction1       2075 non-null   object
#  4   prediction1_conf  2075 non-null   float64
#  5   prediction1_dog   2075 non-null   bool
#  6   Prediction2       2075 non-null   object
#  7   prediction2_conf  2075 non-null   float64
#  8   prediction2_dog   2075 non-null   bool
#  9   Prediction3       2075 non-null   object
#  10  prediction3_conf  2075 non-null   float64
#  11  prediction3_dog   2075 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %% [markdown]
# ## twitter table

# %% [markdown]
# ##### Define
# Drop the unnecessary collumns with most nulls.

# %% [markdown]
# ##### Code

# %%
twitter_clean.drop(['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp'],axis=1,inplace=True)

# %% [markdown]
# ##### Test

# %%
twitter_clean.head(0)
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ##### Define
# Change timestamp to datetime instead of object.

# %% [markdown]
# ##### Code

# %%
twitter_clean['time'] = pd.to_datetime(twitter_clean['timestamp'])

# %% [markdown]
# ##### Test

# %%
twitter_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   object
#  2   source              2356 non-null   object
#  3   text                2356 non-null   object
#  4   expanded_urls       2297 non-null   object
#  5   rating_numerator    2356 non-null   int64
#  6   rating_denominator  2356 non-null   int64
#  7   name                2356 non-null   object
#  8   doggo               2356 non-null   object
#  9   floofer             2356 non-null   object
#  10  pupper              2356 non-null   object
#  11  puppo               2356 non-null   object
#  12  time                2356 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int64(3), object(9)
# memory usage: 239.4+ KB

# %% [markdown]
# ##### Define
# Change tweet_id to object instead of int.

# %% [markdown]
# ##### Code

# %%
twitter_clean['tweet_id'] = twitter_clean['tweet_id'].astype('str')

# %% [markdown]
# ##### Test

# %%
twitter_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   object
#  1   timestamp           2356 non-null   object
#  2   source              2356 non-null   object
#  3   text                2356 non-null   object
#  4   expanded_urls       2297 non-null   object
#  5   rating_numerator    2356 non-null   int64
#  6   rating_denominator  2356 non-null   int64
#  7   name                2356 non-null   object
#  8   doggo               2356 non-null   object
#  9   floofer             2356 non-null   object
#  10  pupper              2356 non-null   object
#  11  puppo               2356 non-null   object
#  12  time                2356 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int64(2), object(10)
# memory usage: 239.4+ KB

# %% [markdown]
# ##### Define
# Drop Max rating numerator 1776 which should be wrong.

# %% [markdown]
# ##### Code

# %%
#Find the index of outlier
twitter_clean.loc[twitter_clean['rating_numerator']== 1776]
# Out:
#                tweet_id                  timestamp  \
# 979  749981277374128128  2016-07-04 15:00:45 +0000
#
#                                                 source  \
# 979  <a href="https://about.twitter.com/products/tw...
#
#                                                   text  \
# 979  This is Atticus. He's quite simply America af....
#
#                                          expanded_urls  rating_numerator  \
# 979  https://twitter.com/dog_rates/status/749981277...              1776
#
#      rating_denominator     name doggo floofer pupper puppo  \
# 979                  10  Atticus  None    None   None  None
#
#                          time
# 979 2016-07-04 15:00:45+00:00

# %%
twitter_clean=twitter_clean.drop(979)

# %% [markdown]
# ##### Test

# %%
twitter_clean.rating_numerator.value_counts()
# Out:
# 12     558
# 11     464
# 10     461
# 13     351
# 9      158
# 8      102
# 7       55
# 14      54
# 5       37
# 6       32
# 3       19
# 4       17
# 1        9
# 2        9
# 420      2
# 0        2
# 15       2
# 75       2
# 60       1
# 20       1
# 24       1
# 26       1
# 44       1
# 50       1
# 165      1
# 80       1
# 84       1
# 88       1
# 144      1
# 182      1
# 143      1
# 666      1
# 960      1
# 17       1
# 27       1
# 45       1
# 99       1
# 121      1
# 204      1
# Name: rating_numerator, dtype: int64

# %% [markdown]
# ##### Define
# Drop row with rating denominator not equal to 10.

# %% [markdown]
# ##### Code

# %%
#Find the row with rating_denominator not equal to 10
twitter_clean.loc[twitter_clean['rating_denominator']!= 10]
# Out:
#                 tweet_id                  timestamp  \
# 313   835246439529840640  2017-02-24 21:54:03 +0000
# 342   832088576586297345  2017-02-16 04:45:50 +0000
# 433   820690176645140481  2017-01-15 17:52:40 +0000
# 516   810984652412424192  2016-12-19 23:06:23 +0000
# 784   775096608509886464  2016-09-11 22:20:06 +0000
# 902   758467244762497024  2016-07-28 01:00:57 +0000
# 1068  740373189193256964  2016-06-08 02:41:38 +0000
# 1120  731156023742988288  2016-05-13 16:15:54 +0000
# 1165  722974582966214656  2016-04-21 02:25:47 +0000
# 1202  716439118184652801  2016-04-03 01:36:11 +0000
# 1228  713900603437621249  2016-03-27 01:29:02 +0000
# 1254  710658690886586372  2016-03-18 02:46:49 +0000
# 1274  709198395643068416  2016-03-14 02:04:08 +0000
# 1351  704054845121142784  2016-02-28 21:25:30 +0000
# 1433  697463031882764288  2016-02-10 16:51:59 +0000
# 1598  686035780142297088  2016-01-10 04:04:10 +0000
# 1634  684225744407494656  2016-01-05 04:11:44 +0000
# ...

# %%
#Drop all row in dataframe which rating_denominator is not equal to 10
twitter_clean.drop(twitter_clean.loc[twitter_clean['rating_denominator']!=10].index, inplace=True)

# %% [markdown]
# ##### Test

# %%
twitter_clean.rating_denominator.value_counts()
# Out:
# 10    2332
# Name: rating_denominator, dtype: int64

# %% [markdown]
# ##### Define
# Change tweet_id to object instead of int.

# %% [markdown]
# #### Code

# %%
twitter_clean['tweet_id'] = twitter_clean['tweet_id'].astype('str')

# %% [markdown]
# #### Test

# %%
twitter_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2332 entries, 0 to 2355
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2332 non-null   object
#  1   timestamp           2332 non-null   object
#  2   source              2332 non-null   object
#  3   text                2332 non-null   object
#  4   expanded_urls       2277 non-null   object
#  5   rating_numerator    2332 non-null   int64
#  6   rating_denominator  2332 non-null   int64
#  7   name                2332 non-null   object
#  8   doggo               2332 non-null   object
#  9   floofer             2332 non-null   object
#  10  pupper              2332 non-null   object
#  11  puppo               2332 non-null   object
#  12  time                2332 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int64(2), object(10)
# memory usage: 255.1+ KB

# %% [markdown]
# ## tweet table

# %% [markdown]
# ##### Define
# Drop unnecessary collumns like (retweets, user_followers).

# %% [markdown]
# ##### Code

# %%
#Drop unnecessary collumns
tweet_clean.drop(['retweets','user_followers'],axis=1,inplace=True)

# %% [markdown]
# ##### Test

# %%
tweet_clean.head(10)
# Out:
#                     favorites  user_favourites            date_time
# tweet_id
# 892420643555336193      38664           135116  2017-08-01 16:23:56
# 892177421306343426      33127           135116  2017-08-01 00:17:27
# 891815181378084864      24939           135116  2017-07-31 00:18:03
# 891689557279858688      42044           135116  2017-07-30 15:58:51
# 891327558926688256      40194           135116  2017-07-29 16:00:24
# 891087950875897856      20157           135116  2017-07-29 00:08:17
# 890971913173991426      11810           135116  2017-07-28 16:27:12
# 890729181411237888      65300           135116  2017-07-28 00:22:40
# 890609185150312448      27702           135116  2017-07-27 16:25:51
# 890240255349198849      31830           135116  2017-07-26 15:59:51

# %% [markdown]
# ##### Code

# %% [markdown]
# ## Tideness

# %% [markdown]
# ##### Define
# Create a column Total Rating which includes (rating_numerator/rating_denominator) in twitter table.

# %% [markdown]
# ##### Code

# %%
twitter_clean['Total Rating'] = twitter_clean['rating_numerator']/twitter_clean['rating_denominator']

# %% [markdown]
# ##### Test

# %%
twitter_clean.head(3)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
#
# ...

# %% [markdown]
# ##### Define
# Combine two dataframes(twitter_clean with image_predictions_clean).

# %% [markdown]
# ##### Code

# %%
df_merged = pd.merge(twitter_clean,image_predictions_clean,on='tweet_id',how='inner')

# %% [markdown]
# #### Test

# %%
df_merged.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %% [markdown]
# <a id='Storing'></a>
# ## Storing and Acting on Wrangled Data

# %%
#Store Data
df_merged.to_csv('twitter_archive_master.csv')
